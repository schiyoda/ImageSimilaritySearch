# %% [markdown]
# # 抽出した特徴量のロード

# %% [markdown]
# 右側 Data パネルの Connectionsから "Insert to code" で credential を入力

# %%
from ibm_botocore.client import Config
import ibm_boto3

cos = ibm_boto3.client(service_name='s3',
    ibm_api_key_id=credentials_1['api_key'],
    ibm_service_instance_id=credentials_1['resource_instance_id'],
    ibm_auth_endpoint=credentials_1['iam_url'],
    config=Config(signature_version='oauth'),
    endpoint_url=credentials_1['url'])

# %% [markdown]
# bucket_nameを指定

# %%
import os

if not os.path.exists('./model'):
    os.mkdir('./model')

bucket_name = ''

cos.download_file(Bucket=bucket_name,Key='inception-base-0.2-model.h5',Filename='model/inception-base-0.2-model.h5')
cos.download_file(Bucket=bucket_name,Key='inception-triplet-0.2-history.p',Filename='model/inception-triplet-0.2-history.p')

# %% [markdown]
# # history の表示

# %%
import pickle

history = pickle.load( open( 'model/inception-triplet-0.2-history.p', 'rb' ) )

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# Visualize the training process
train_loss = history['loss']
val_loss = history['val_loss']

fig, ax = plt.subplots(figsize=(10, 7))
ax.plot(train_loss, label='Training Loss')
ax.plot(val_loss, label='Validation Loss')
ax.set_title('Loss vs. Epochs', fontsize=16)
ax.set_xlabel('Epochs', fontsize=14)
ax.set_ylabel('Loss', fontsize=14)
ax.legend(fontsize=14)
ax.grid(True)
plt.show()
